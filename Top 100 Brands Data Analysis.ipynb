# %% [markdown]
# ## <span style="color:brown;"><center> Worldwide Top 100 Brands Data Analysis </center></span>

# %%
# Import required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Read the Data

# %%
# Read and see the data
brands=pd.read_csv('top_100_brand_global-2022.csv',encoding='ISO-8859-1')
brands
# Out:
#         Brand                      Founded By/How it was founded  Founded In  \
# 0       Apple             Steve Jobs, Steve Wozniak,Ronald Wayne        1976
# 1      Amazon                                         Jeff Bezos        1994
# 2      Google                            Larry Page, Sergey Brin        1998
# 3   Microsoft                             Bill Gates, Paul Allen        1975
# 4     Walmart                                         Sam Walton        1962
# ..        ...                                                ...         ...
# 95       CRCC  Formerly an arm of People's Liberation Army, t...        1948
# 96  Walgreens                           Charles Rudolph Walgreen        1901
# 97   Vodafone                       Ernest Harrison, Gerry Whent        1991
# 98       Aldi                                Karl, Theo Albrecht        1946
# 99        RBC  The Merchants Bank of Halifax, found in 1864 a...        1864
#
# ...

# %% [markdown]
# #### Understand and Clean the Data

# %%
# See the Total Rows and Columns or the Shape of Data
brands.shape
# Out:
# (100, 14)

# %%
# See all Columns
brands.columns
# Out:
# Index(['Brand', 'Founded By/How it was founded', 'Founded In', 'Country',
#        'Key People', 'Genre/Industry', 'Website', 'Rank in 2022',
#        'Rank in 2021', 'Brand Value ($M) in 2022', 'Brand Value ($M) in 2021',
#        '% Change', 'Rating in 2022', 'Rating in 2021 '],
#       dtype='object')

# %%
# See the Info or Structure of dataframe or dataset
brands.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Brand                          100 non-null    object
#  1   Founded By/How it was founded  100 non-null    object
#  2   Founded In                     100 non-null    int64
#  3   Country                        100 non-null    object
#  4   Key People                     100 non-null    object
#  5   Genre/Industry                 100 non-null    object
#  6   Website                        100 non-null    object
#  7   Rank in 2022                   100 non-null    int64
#  8   Rank in 2021                   100 non-null    object
#  9   Brand Value ($M) in 2022       100 non-null    float64
#  10  Brand Value ($M) in 2021       100 non-null    float64
#  11  % Change                       100 non-null    object
# ...

# %%
# convert the datatypes of some columns
brands=brands.astype({"Founded In":"object"})
brands=brands.astype({'Rank in 2022':"object"})
brands.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Brand                          100 non-null    object
#  1   Founded By/How it was founded  100 non-null    object
#  2   Founded In                     100 non-null    object
#  3   Country                        100 non-null    object
#  4   Key People                     100 non-null    object
#  5   Genre/Industry                 100 non-null    object
#  6   Website                        100 non-null    object
#  7   Rank in 2022                   100 non-null    object
#  8   Rank in 2021                   100 non-null    object
#  9   Brand Value ($M) in 2022       100 non-null    float64
#  10  Brand Value ($M) in 2021       100 non-null    float64
#  11  % Change                       100 non-null    object
# ...

# %%
# Check no. of Unique values
brands.nunique()
# Out:
# Brand                            100
# Founded By/How it was founded     99
# Founded In                        76
# Country                           14
# Key People                        97
# Genre/Industry                    54
# Website                          100
# Rank in 2022                     100
# Rank in 2021                      99
# Brand Value ($M) in 2022         100
# Brand Value ($M) in 2021         100
# % Change                          50
# Rating in 2022                     7
# Rating in 2021                     8
# dtype: int64

# %%
# Check the Null values (if any)
brands.isnull().sum()
# Out:
# Brand                            0
# Founded By/How it was founded    0
# Founded In                       0
# Country                          0
# Key People                       0
# Genre/Industry                   0
# Website                          0
# Rank in 2022                     0
# Rank in 2021                     0
# Brand Value ($M) in 2022         0
# Brand Value ($M) in 2021         0
# % Change                         0
# Rating in 2022                   0
# Rating in 2021                   0
# dtype: int64

# %%
# See the Unique values in 'Rating in 2022' column
brands['Rating in 2022'].unique()
# Out:
# array(['AAA', 'AAA+', 'AAA-', 'AA+', 'AA', 'AA-', 'A+'], dtype=object)

# %%
# Check the data type of all columns
brands.dtypes
# Out:
# Brand                             object
# Founded By/How it was founded     object
# Founded In                        object
# Country                           object
# Key People                        object
# Genre/Industry                    object
# Website                           object
# Rank in 2022                      object
# Rank in 2021                      object
# Brand Value ($M) in 2022         float64
# Brand Value ($M) in 2021         float64
# % Change                          object
# Rating in 2022                    object
# Rating in 2021                    object
# dtype: object

# %%
# Check the Duplicate rows (if any)
brands[brands.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Brand, Founded By/How it was founded, Founded In, Country, Key People, Genre/Industry, Website, Rank in 2022, Rank in 2021, Brand Value ($M) in 2022, Brand Value ($M) in 2021, % Change, Rating in 2022, Rating in 2021 ]
# Index: []

# %% [markdown]
# #### So, we have clean dataframe without any Duplicate and Null values. And now, we can move on to the Analysis Part.

# %% [markdown]
# #### Analyse the Data

# %%
# Check the overall Brand Value in 2022 (in Milion Dollars) by all Brands
brands['Brand Value ($M) in 2022'].sum().round(2)
# Out:
# 4759873.68

# %%
# Check the overall Brand Value in 2021 (in Million Dollars) by all Brands
brands['Brand Value ($M) in 2021'].sum().round(2)
# Out:
# 4104898.91

# %%
# Check the Statistics of Numerical columns
brands.describe()
# Out:
#        Brand Value ($M) in 2022  Brand Value ($M) in 2021
# count                100.000000                100.000000
# mean               47598.736800              41048.989100
# std                54600.630407              40424.690221
# min                19039.810000              12297.960000
# 25%                24291.250000              21388.482500
# 50%                32104.380000              29471.930000
# 75%                47552.012500              47437.320000
# max               355079.970000             263374.700000

# %%
# Check the No. of Brands (in the top 100) by Country
brands['Country'].value_counts()
# Out:
# Country
# United States     46
# China             23
# Germany            8
# Japan              7
# South Korea        4
# United Kingdom     4
# Saudi Arabia       1
# Ireland            1
# England            1
# India              1
# France             1
# Switerland         1
# Taiwan             1
# Canada             1
# Name: count, dtype: int64

# %% [markdown]
# #### Here we found USA has most of the Companies in top 100 Worldwide and China in the Second place with 23 Brands and rest of the Countries (12 countries) have less than 10 Brands in Worldwide top 100 list.
# #### Let's create a barplot to see in the visual form.

# %%
brcv=brands['Country'].value_counts().values
brci=brands['Country'].value_counts().index

# %%
ax=sns.barplot(brands,x=brcv,y=brci,errwidth=0)
for i in ax.containers:
    ax.bar_label(i,)

# %%
# Check how many US Brands founded after 2000
brands[(brands.Country=='United States') & (brands['Founded In']>2000)].value_counts().sum()
# Out:
# 6

# %% [markdown]
# #### Here we can see only 6 US Companies or Brands founded after 2000 from the list of 46 Brands.

# %%
# See the US Brands details which founded after the Year 2000
brands[(brands.Country=='United States') & (brands['Founded In']>2000)]
# Out:
#                 Brand                      Founded By/How it was founded  \
# 6            Facebook                   Mark Zuckerberg, Eduardo Saverin
# 27              Tesla                   Martin Eberhard, Marc Tarpenning
# 46          Instagram                        Kevin Systrom, Mike Krieger
# 78            YouTube               Chad Hurley, Steve Chen, Jawed Karim
# 84               Uber                      Garrett Camp, Travis Kalanick
# 86  Dell Technologies  Michael Dell( formed as merger of Dell and EMC...
#
#    Founded In        Country                       Key People  \
# 6        2004  United States             Mark Zuckerberg(CEO)
# 27       2003  United States                   Elon Musk(CEO)
# 46       2010  United States  Adam Mosseri(Head Of Instagram)
# 78       2005  United States              Susan Wojcicki(CEO)
# 84       2009  United States           Dara Khosrowshahi(CEO)
# 86       2016  United States   Michael Dell(Chairman and CEO)
#
# ...

# %%
# Check how many US Brands founded in between 1950 to 2000
brands[(brands.Country=='United States') & (brands['Founded In']>1950) & (brands['Founded In']<2000)].value_counts().sum()
# Out:
# 23

# %%
# Check how many US Brands founded in between 1900 to 1950
brands[(brands.Country=='United States') & (brands['Founded In']>1900) & (brands['Founded In']<1950)].value_counts().sum()
# Out:
# 9

# %%
# Check how many US brands founded before 1900
brands[(brands.Country=='United States') & (brands['Founded In']<1900)].value_counts().sum()
# Out:
# 8

# %%
# See the US Brands details which founded before the Year 1900
brands[(brands.Country=='United States') & (brands['Founded In']<1900)]
# Out:
#                Brand                      Founded By/How it was founded  \
# 25              AT&T     Alexander Graham Bell, Gardiner Greene Hubbard
# 43         Coca-Cola                               John Stith Pemberton
# 51             Chase  Subsidiary of JPMorgan Chase. Was known as Cha...
# 52       Wells Fargo                         Henry Wells, William Fargo
# 57         JP Morgan                                       J. P. Morgan
# 62  American Express  Founded as a joint-stock corporation by the me...
# 91             Pepsi                                      Caleb Bradham
# 94  General Electric     Charles A. Coffin, Thomas Edison, J. P. Morgan
#
#    Founded In        Country  \
# 25       1885  United States
# 43       1886  United States
# 51       1799  United States
# 52       1852  United States
# 57       1871  United States
# 62       1850  United States
# 91       1893  United States
# 94       1892  United States
#
# ...

# %%
# Check how many China Brands founded after Year 2000
brands[(brands.Country=='China') & (brands['Founded In']>2000)].value_counts().sum()
# Out:
# 6

# %%
# See the China Brands details which founded after 2000
brands[(brands.Country=='China') & (brands['Founded In']>2000)]
# Out:
#             Brand Founded By/How it was founded Founded In Country  \
# 12         WeChat                       Tencent       2011   China
# 15     State Grid        State Council of China       2002   China
# 17  TikTok/Douyin                     ByteDance       2016   China
# 21         Taobao                 Alibaba group       2003   China
# 24          Tmall                 Alibaba group       2008   China
# 63         JD.com                 Liu Qiangdong       2009   China
#
#                                           Key People  \
# 12  Ma Huateng(CEO of Tencent which develops WeChat)
# 15                             Shu Yinbiao(Chairman)
# 17                                 Shou Zi Chew(CEO)
# 21                        Trudy Dai Shan(chairwoman)
# 24                        Trudy Dai Shan(chairwoman)
# 63                         Xu Lei(President and CEO)
#
#                                        Genre/Industry  \
# 12  Instant messaging, social Media and mobile pay...
# ...

# %%
# Check how many China brands founded between 1950 to 2000
brands[(brands.Country=='China') & (brands['Founded In']>1950) & (brands['Founded In']<2000)].value_counts().sum()
# Out:
# 13

# %%
# Check how many Japan brands founded before 1950
brands[(brands.Country=='Japan') & (brands['Founded In']<1950)].value_counts().sum()
# Out:
# 6

# %% [markdown]
# #### Here we found Japan has 7 Brands in Top 100 Worldwide list in which 6 was founded before 1950 and only one Brand founded after 1950.
# **Let's check that brand**

# %%
# Check Japan Brand which was founded after 1950
brands[(brands.Country=='Japan') & (brands['Founded In']>1950)]
# Out:
#         Brand Founded By/How it was founded Founded In Country  \
# 34  NTT Group           Government of Japan       1952   Japan
#
#             Key People      Genre/Industry  \
# 34  Akira Shimada(CEO)  Telecommunications
#
#                                               Website Rank in 2022  \
# 34  https://group.ntt/en/ AND https://www.global.ntt/           35
#
#    Rank in 2021  Brand Value ($M) in 2022  Brand Value ($M) in 2021 % Change  \
# 34           37                   40691.0                   34238.0      19%
#
#    Rating in 2022 Rating in 2021
# 34            AA+              AA

# %%
# Let's check the Indian brand in Top 100 Worldwide List
brands[brands.Country=='India']
# Out:
#          Brand Founded By/How it was founded Founded In Country  \
# 77  TATA Group                 Jamsedji Tata       1868   India
#
#                                            Key People Genre/Industry  \
# 77  Natarajan Chandrasekaran(Chairman and Managing...   Conglomerate
#
#                   Website Rank in 2022 Rank in 2021  Brand Value ($M) in 2022  \
# 77  https://www.tata.com/           78           77                   23919.8
#
#     Brand Value ($M) in 2021 % Change Rating in 2022 Rating in 2021
# 77                   21283.1      12%           AAA-            AAA-

# %% [markdown]
# #### Only Indian Brand in Top 100 Worldwide list is TATA Group. which Rank in 2022 is 78.

# %% [markdown]
# #### Let's check how many Brands have their Brand value more than $50000 Million in 2022

# %%
# Check no. of Brands which Brand value in 2022 is more than 50000 Million Dollars
brands[(brands['Brand Value ($M) in 2022']>50000)].value_counts().sum()
# Out:
# 22

# %% [markdown]
# #### And now, Check how many Brands have their Brand value more than $50000 Million in 2021

# %%
# Check no. of Brands which Brand value in 2021 is more than 50000 Millin Dollars
brands[(brands['Brand Value ($M) in 2021']>50000)].value_counts().sum()
# Out:
# 23

# %% [markdown]
# #### So, here we found in 2022 there are 22 brands but in 2021 there are 23 brands which brand values more than $50000 Million. Let's see that brand

# %%
# Check which Brands brand value is less than $50000 Million in 2022 and more than $50000 Million in 2021
brands[(brands['Brand Value ($M) in 2022']<50000) & (brands['Brand Value ($M) in 2021']>50000)]
# Out:
#       Brand                      Founded By/How it was founded Founded In  \
# 25     AT&T     Alexander Graham Bell, Gardiner Greene Hubbard       1885
# 26  Tencent  Pony Ma, Tony Zhang, Xu Chenye, Charles Chen, ...       1998
#
#           Country         Key People                  Genre/Industry  \
# 25  United States  John Stankey(CEO)  Telecommunications, Technology
# 26          China       Pony Ma(CEO)                    Conglomerate
#
#                                      Website Rank in 2022 Rank in 2021  \
# 25                    https://about.att.com/           26           21
# 26  https://www.tencent.com/en-us/index.html           27           14
#
#     Brand Value ($M) in 2022  Brand Value ($M) in 2021 % Change  \
# 25                  47008.54                  51372.34      -8%
# 26                  46652.50                  56432.39     -17%
#
#    Rating in 2022 Rating in 2021
# 25             AA              AA
# 26           AAA-             AAA

# %% [markdown]
# #### Result says there is two Brands but we thought only one let's check that Brand which Brand Value is less than $50000 Million in 2021 but more than in 2022

# %%
# Check Brands which brand value is more than 50000 million $ in 2022 and less than 50000 million $ in 2021
brands[(brands['Brand Value ($M) in 2022']>50000) & (brands['Brand Value ($M) in 2021']<50000)]
# Out:
#             Brand Founded By/How it was founded Founded In Country  \
# 17  TikTok/Douyin                     ByteDance       2016   China
#
#            Key People Genre/Industry  \
# 17  Shou Zi Chew(CEO)  Video Hosting
#
#                                               Website Rank in 2022  \
# 17  https://www.tiktok.com/\n\nhttps://www.douyin....           18
#
#    Rank in 2021  Brand Value ($M) in 2022  Brand Value ($M) in 2021 % Change  \
# 17            -                  58979.93                   18700.0     215%
#
#    Rating in 2022 Rating in 2021
# 17            AA+               -

# %% [markdown]
# #### Here we found Tiktok (Brand) brand value hass increasing with huge percentage i.e. 215%

# %%
# Check how many Brands which rating is AAA+ in 2022
brands[(brands['Rating in 2022']=='AAA+')].value_counts().sum()
# Out:
# 12

# %%
# Check how many Brands which rating is A+ in 2022
brands[(brands['Rating in 2022']=='A+')].value_counts().sum()
# Out:
# 1

# %% [markdown]
# #### We found only 1 Brand has A+ rating in 2022, let's see that Brand

# %%
# See the Brand which rating is A+ in 2022
brands[(brands['Rating in 2022']=='A+')]
# Out:
#      Brand Founded By/How it was founded Founded In Country Key People  \
# 74  Mitsui              Mitsui Takatoshi       1876   Japan          -
#
#    Genre/Industry                                  Website Rank in 2022  \
# 74   Conglomerate  https://www.mitsui.com/jp/en/index.html           75
#
#    Rank in 2021  Brand Value ($M) in 2022  Brand Value ($M) in 2021 % Change  \
# 74           73                   24329.0                  22495.82       8%
#
#    Rating in 2022 Rating in 2021
# 74             A+              A+

# %% [markdown]
# #### Let's remove the '%' sign from '% change' column

# %%
# Save the new integer value without % sign in new column
brands[['Change %']]=brands['% Change'].str.extract('(\d+)').astype(int)

# %%
# Check brands data with new column
brands.head()
# Out:
#        Brand           Founded By/How it was founded Founded In  \
# 0      Apple  Steve Jobs, Steve Wozniak,Ronald Wayne       1976
# 1     Amazon                              Jeff Bezos       1994
# 2     Google                 Larry Page, Sergey Brin       1998
# 3  Microsoft                  Bill Gates, Paul Allen       1975
# 4    Walmart                              Sam Walton       1962
#
#          Country          Key People  \
# 0  United States       Tim Cook(CEO)
# 1  United States     Andy Jassy(CEO)
# 2  United States  Sundar Pichai(CEO)
# 3  United States  Satya Nadella(CEO)
# 4  United States  Doug McMillon(CEO)
#
#                                       Genre/Industry  \
# 0  Consumer electronics, Software Service, Online...
# 1  E-Commerce, Cloud Computing, Artificial Intell...
# 2  Artificial Intelligence, Advertising, Cloud Co...
# 3                             Information Technology
# 4                                             Retail
#
# ...

# %%
# Let's see those Brands which Brand value changed % is more than 50
brands[(brands['Change %']>50)]
# Out:
#             Brand Founded By/How it was founded Founded In  Country  \
# 17  TikTok/Douyin                     ByteDance       2016    China
# 29  Allianz Group               Carl von Thieme       1890  Germany
# 80  Louis Vuitton                 Louis Vuitton       1955   France
# 92           TSMC                  Morris Chang       1987   Taiwan
#
#                          Key People  \
# 17                Shou Zi Chew(CEO)
# 29                 Oliver Bäte(CEO)
# 80  Michael Burke(Chairman and CEO)
# 92                    C.C. Wei(CEO)
#
#                                        Genre/Industry  \
# 17                                      Video Hosting
# 29                                 Financial services
# 80                                            Fashion
# 92  Semiconductors, GPUs, Graphic cards, Consumer ...
#
#                                               Website Rank in 2022  \
# 17  https://www.tiktok.com/\n\nhttps://www.douyin....           18
# ...

# %% [markdown]
# #### Here we found Brand Value of Tiktok (Douyin) has increased by 215% followed by Allianz Group with 198%.

# %%
# Check the Brands which brand value in 2022 is less than in 2021
brands[(brands['Brand Value ($M) in 2022']) < (brands['Brand Value ($M) in 2021'])].value_counts().sum()
# Out:
# 17

# %% [markdown]
# #### We found 17 Brands faced loss in their Brand values, let's see those 17 Brands

# %%
# See the Brands which brand value in 2022 is less than in 20221
brands[(brands['Brand Value ($M) in 2022']) < (brands['Brand Value ($M) in 2021'])]
# Out:
#           Brand                      Founded By/How it was founded Founded In  \
# 12       WeChat                                            Tencent       2011
# 20      Ping An                                         Ma Mingzhe       1988
# 25         AT&T     Alexander Graham Bell, Gardiner Greene Hubbard       1885
# 26      Tencent  Pony Ma, Tony Zhang, Xu Chenye, Charles Chen, ...       1998
# 31       Moutai                              Kweichow Moutai Group       1999
# 32   Volkswagen                                German Labour Front       1937
# 38          BMW   Camillo Castiglioni, Franz Josef Popp, Karl Rapp       1916
# 45      Porsche                                  Ferdinand Porsche       1931
# 52  Wells Fargo                         Henry Wells, William Fargo       1852
# 54   PetroChina  Founded as a joint stock company with limited ...       1999
# 60        Honda                                     Soichiro Honda       1946
# ...

# %% [markdown]
# #### Here we found, Alibaba.com faced Maximum loss or negative change percentage in brand value i.e. 42% (negative 42%).

# %%
# Check how many brands are from Retail Industry
brands[(brands['Genre/Industry']=='Retail')].value_counts().sum()
# Out:
# 8

# %%
# Check how many brands are Conglomerate
brands[(brands['Genre/Industry']=='Conglomerate')].value_counts().sum()
# Out:
# 11

# %% [markdown]
# ### Conclusion:
# (This dataset is for 2021 and 2022 only)
# 1. In the Top 100 Brands world wide Ranking US has maximum number (46) of Brands. and China in the Second place with 23 Brands.
# 2. Japan has 7 brands in the top 100 in which 6 was founded before 1950 and only 1 brand founded after 1950.
# 3. India has only 1 Brand (Tata Group) in the Top 100 worldwide ranking
# 4. Tiktok/Douyin brand value has increased by 215%. (most profitable)
# 5. Alibaba brand value has decreased by 42%. (faced huge loss)
# 6. In the Top 100 list 11 Brands are from Conglomerate Industry and 8 Brands from Retail Industry.
# 7. Top 3 Brands (Apple,Amazon,Google) are work in Multiple Industries or fields (i.e. AI,Consumer Electronics,Entertainment,Cloud Computing, etc.).
